# %%
import pandas as pd

# %%
df = pd.read_csv("CricketTestMatchData.csv")

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 3     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 61   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7  626+   6
# ...

# %%
df  = df.rename(columns = {"Mat": "Matched_Played", "NO": "No_Outs", "HS": "Highest_Inns_Score", "BF": "Balls_Faced", "SR": "Batting_Strike_Rate"})

# %%
df.head()
# Out:
#              Player       Span  Matched_Played  Inns  No_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948              52    80       10  6996
# 1    AC Voges (AUS)  2015-2016              20    31        7  1485
# 2   RG Pollock (SA)  1963-1970              23    41        4  2256
# 3   GA Headley (WI)  1930-1954              22    40        4  2190
# 4   GA Headley (WI)  1930-1954              22    40        4  2190
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 0                334  99.94       9800+                58.60   29  13  7
# 1               269*  61.87        2667                55.68    5   4  2
# 2                274  60.97       1707+                54.48    7  11  1
# 3               270*  60.83        416+                56.00   10   5  2
# 4               270*  60.83        416+                56.00   10   5  2
#
#      4s  6s
# 0  626+   6
# 1   186   5
# 2  246+  11
# 3  104+   1
# 4  104+   1

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matched_Played         False
# Inns                   False
# No_Outs                False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df["Balls_Faced"].isna() == 1]
# Out:
#              Player       Span  Matched_Played  Inns  No_Outs  Runs  \
# 9    ED Weekes (WI)  1948-1958              48    81        5  4455
# 17  CL Walcott (WI)  1948-1960              44    74        7  3798
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 9                 207  58.61         NaN                  NaN   15  19  6
# 17                220  56.68         NaN                  NaN   15  14  1
#
#       4s  6s
# 9   258+   2
# 17  107+  11

# %%
df["Balls_Faced"] = df["Balls_Faced"].fillna(0)

# %%
df["Batting_Strike_Rate"] = df["Batting_Strike_Rate"].fillna(0)

# %%
df[df["Player"] == "ED Weekes (WI)"]
# Out:
#            Player       Span  Matched_Played  Inns  No_Outs  Runs  \
# 9  ED Weekes (WI)  1948-1958              48    81        5  4455
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 9                207  58.61           0                  0.0   15  19  6
#
#      4s 6s
# 9  258+  2

# %%
df[df["Player"] == "CL Walcott (WI)"]
# Out:
#              Player       Span  Matched_Played  Inns  No_Outs  Runs  \
# 17  CL Walcott (WI)  1948-1960              44    74        7  3798
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 17                220  56.68           0                  0.0   15  14  1
#
#       4s  6s
# 17  107+  11

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 66, dtype: bool

# %%
df[df["Player"].duplicated() == 1]
# Out:
#              Player       Span  Matched_Played  Inns  No_Outs  Runs  \
# 4   GA Headley (WI)  1930-1954              22    40        4  2190
# 12   GS Sobers (WI)  1954-1974              93   160       21  8032
# 16   JB Hobbs (ENG)  1908-1930              61   102        7  5410
# 54    V Kohli (IND)  2011-2024             113   191       11  8848
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 4                270*  60.83        416+                56.00   10   5   2
# 12               365*  57.78       4063+                53.58   26  30  12
# 16                211  56.94       5363+                46.22   15  28   4
# 54               254*  49.15       15924                55.56   29  30  14
#
#       4s   6s
# 4   104+    1
# 12  593+  32+
# 16  276+    8
# 54   991   26

# %%
df[df["Player"].isin(["GA Headley (WI)", "GS Sobers (WI)", "JB Hobbs (ENG)", "V Kohli (IND)"])]
# Out:
#              Player       Span  Matched_Played  Inns  No_Outs  Runs  \
# 3   GA Headley (WI)  1930-1954              22    40        4  2190
# 4   GA Headley (WI)  1930-1954              22    40        4  2190
# 11   GS Sobers (WI)  1954-1974              93   160       21  8032
# 12   GS Sobers (WI)  1954-1974              93   160       21  8032
# 15   JB Hobbs (ENG)  1908-1930              61   102        7  5410
# 16   JB Hobbs (ENG)  1908-1930              61   102        7  5410
# 53    V Kohli (IND)  2011-2024             113   191       11  8848
# 54    V Kohli (IND)  2011-2024             113   191       11  8848
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 3                270*  60.83        416+                56.00   10   5   2
# 4                270*  60.83        416+                56.00   10   5   2
# 11               365*  57.78       4063+                53.58   26  30  12
# ...

# %%
df = df.drop_duplicates()

# %%
df[df["Player"].isin(["GA Headley (WI)", "GS Sobers (WI)", "JB Hobbs (ENG)", "V Kohli (IND)"])]
# Out:
#              Player       Span  Matched_Played  Inns  No_Outs  Runs  \
# 3   GA Headley (WI)  1930-1954              22    40        4  2190
# 11   GS Sobers (WI)  1954-1974              93   160       21  8032
# 15   JB Hobbs (ENG)  1908-1930              61   102        7  5410
# 53    V Kohli (IND)  2011-2024             113   191       11  8848
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 3                270*  60.83        416+                56.00   10   5   2
# 11               365*  57.78       4063+                53.58   26  30  12
# 15                211  56.94       5363+                46.22   15  28   4
# 53               254*  49.15       15924                55.56   29  30  14
#
#       4s   6s
# 3   104+    1
# 11  593+  32+
# 15  276+    8
# 53   991   26

# %%
df["Span"].str.split(pat = "-")
# Out:
# 0     [1928, 1948]
# 1     [2015, 2016]
# 2     [1963, 1970]
# 3     [1930, 1954]
# 5     [1924, 1935]
#           ...
# 61    [1965, 1981]
# 62    [2002, 2014]
# 63    [1924, 1934]
# 64    [1930, 1938]
# 65    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df["Rookie_Year"] = df["Span"].str.split(pat = "-").str[0]

# %%
df["Final_Year"] = df["Span"].str.split(pat = "-").str[1]

# %%
df
# Out:
#                Player       Span  Matched_Played  Inns  No_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948              52    80       10  6996
# 1      AC Voges (AUS)  2015-2016              20    31        7  1485
# 2     RG Pollock (SA)  1963-1970              23    41        4  2256
# 3     GA Headley (WI)  1930-1954              22    40        4  2190
# 5   H Sutcliffe (ENG)  1924-1935              54    84        9  4555
# ..                ...        ...             ...   ...      ...   ...
# 61   KD Walters (AUS)  1965-1981              74   125       14  5357
# 62  GC Smith (ICC/SA)  2002-2014             117   205       13  9265
# 63  WH Ponsford (AUS)  1924-1934              29    48        4  2122
# 64    SJ McCabe (AUS)  1930-1938              39    62        5  2748
# 65   DR Jardine (ENG)  1928-1934              22    33        6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# ...

# %%
df = df.drop(["Span"], axis = 1)

# %%
df.head()
# Out:
#               Player  Matched_Played  Inns  No_Outs  Runs Highest_Inns_Score  \
# 0   DG Bradman (AUS)              52    80       10  6996                334
# 1     AC Voges (AUS)              20    31        7  1485               269*
# 2    RG Pollock (SA)              23    41        4  2256                274
# 3    GA Headley (WI)              22    40        4  2190               270*
# 5  H Sutcliffe (ENG)              54    84        9  4555                194
#
#      Ave Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0  99.94       9800+                58.60   29  13  7  626+   6        1928
# 1  61.87        2667                55.68    5   4  2   186   5        2015
# 2  60.97       1707+                54.48    7  11  1  246+  11        1963
# 3  60.83        416+                56.00   10   5  2  104+   1        1930
# 5  60.73       6558+                34.59   16  23  2  202+   6        1924
#
#   Final_Year
# 0       1948
# 1       2016
# ...

# %%
#the solution below is also a solution but not as straightfoward as the second solution

# %%
df["Player"].str.split("(").str[1].str.replace(")", "")
# Out:
# 0        AUS
# 1        AUS
# 2         SA
# 3         WI
# 5        ENG
#        ...
# 61       AUS
# 62    ICC/SA
# 63       AUS
# 64       AUS
# 65       ENG
# Name: Player, Length: 62, dtype: object

# %%
df["Player"].str.extract(r"\((\w+)\)")
# Out:
#       0
# 0   AUS
# 1   AUS
# 2    SA
# 3    WI
# 5   ENG
# ..  ...
# 61  AUS
# 62  NaN
# 63  AUS
# 64  AUS
# 65  ENG
#
# [62 rows x 1 columns]

# %%
df["Country_Or_State"] = df["Player"].str.extract(r"\((\w+)\)")

# %%
df
# Out:
#                Player  Matched_Played  Inns  No_Outs  Runs Highest_Inns_Score  \
# 0    DG Bradman (AUS)              52    80       10  6996                334
# 1      AC Voges (AUS)              20    31        7  1485               269*
# 2     RG Pollock (SA)              23    41        4  2256                274
# 3     GA Headley (WI)              22    40        4  2190               270*
# 5   H Sutcliffe (ENG)              54    84        9  4555                194
# ..                ...             ...   ...      ...   ...                ...
# 61   KD Walters (AUS)              74   125       14  5357                250
# 62  GC Smith (ICC/SA)             117   205       13  9265                277
# 63  WH Ponsford (AUS)              29    48        4  2122                266
# 64    SJ McCabe (AUS)              39    62        5  2748                232
# 65   DR Jardine (ENG)              22    33        6  1296                127
#
# ...

# %%
df.dtypes
# Out:
# Player                  object
# Matched_Played           int64
# Inns                     int64
# No_Outs                  int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country_Or_State        object
# dtype: object

# %%
df["Highest_Inns_Score"] = df["Highest_Inns_Score"].str.split(pat = "*").str[0]

# %%
df
# Out:
#                Player  Matched_Played  Inns  No_Outs  Runs Highest_Inns_Score  \
# 0    DG Bradman (AUS)              52    80       10  6996                334
# 1      AC Voges (AUS)              20    31        7  1485                269
# 2     RG Pollock (SA)              23    41        4  2256                274
# 3     GA Headley (WI)              22    40        4  2190                270
# 5   H Sutcliffe (ENG)              54    84        9  4555                194
# ..                ...             ...   ...      ...   ...                ...
# 61   KD Walters (AUS)              74   125       14  5357                250
# 62  GC Smith (ICC/SA)             117   205       13  9265                277
# 63  WH Ponsford (AUS)              29    48        4  2122                266
# 64    SJ McCabe (AUS)              39    62        5  2748                232
# 65   DR Jardine (ENG)              22    33        6  1296                127
#
# ...

# %%
df["Highest_Inns_Score"].astype('int')
# Out:
# 0     334
# 1     269
# 2     274
# 3     270
# 5     194
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: Highest_Inns_Score, Length: 62, dtype: int64

# %%
df["Balls_Faced"] = df["Balls_Faced"].str.split(pat = "+").str[0]

# %%
df
# Out:
#                Player  Matched_Played  Inns  No_Outs  Runs Highest_Inns_Score  \
# 0    DG Bradman (AUS)              52    80       10  6996                334
# 1      AC Voges (AUS)              20    31        7  1485                269
# 2     RG Pollock (SA)              23    41        4  2256                274
# 3     GA Headley (WI)              22    40        4  2190                270
# 5   H Sutcliffe (ENG)              54    84        9  4555                194
# ..                ...             ...   ...      ...   ...                ...
# 61   KD Walters (AUS)              74   125       14  5357                250
# 62  GC Smith (ICC/SA)             117   205       13  9265                277
# 63  WH Ponsford (AUS)              29    48        4  2122                266
# 64    SJ McCabe (AUS)              39    62        5  2748                232
# 65   DR Jardine (ENG)              22    33        6  1296                127
#
# ...

# %%
df = df.astype({"Rookie_Year": "int", "Final_Year": "int"})

# %%
df.dtypes
# Out:
# Player                  object
# Matched_Played           int64
# Inns                     int64
# No_Outs                  int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int64
# Final_Year               int64
# Country_Or_State        object
# dtype: object

# %%
df["Matched_Played"].astype('int')
# Out:
# 0      52
# 1      20
# 2      23
# 3      22
# 5      54
#      ...
# 61     74
# 62    117
# 63     29
# 64     39
# 65     22
# Name: Matched_Played, Length: 62, dtype: int64

# %%
df["Highest_Inns_Score"].astype('int')
# Out:
# 0     334
# 1     269
# 2     274
# 3     270
# 5     194
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: Highest_Inns_Score, Length: 62, dtype: int64

# %%
df.dtypes
# Out:
# Player                  object
# Matched_Played           int64
# Inns                     int64
# No_Outs                  int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int64
# Final_Year               int64
# Country_Or_State        object
# dtype: object

# %%
df.isnull().any()
# Out:
# Player                 False
# Matched_Played         False
# Inns                   False
# No_Outs                False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country_Or_State        True
# dtype: bool

# %%
df[df["Balls_Faced"].isna() == 1]
# Out:
#              Player  Matched_Played  Inns  No_Outs  Runs Highest_Inns_Score  \
# 9    ED Weekes (WI)              48    81        5  4455                207
# 17  CL Walcott (WI)              44    74        7  3798                220
#
#       Ave Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s  Rookie_Year  \
# 9   58.61         NaN                  0.0   15  19  6  258+   2         1948
# 17  56.68         NaN                  0.0   15  14  1  107+  11         1948
#
#     Final_Year Country_Or_State
# 9         1958               WI
# 17        1960               WI

# %%
df["Balls_Faced"] = df["Balls_Faced"].fillna(0)

# %%
df[df["Balls_Faced"].isna() == 1]
# Out:
# Empty DataFrame
# Columns: [Player, Matched_Played, Inns, No_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s, Rookie_Year, Final_Year, Country_Or_State]
# Index: []

# %%
df["Balls_Faced"].astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df["Balls_Faced"].astype("int")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
# ...

# %%
pd.set_option("display.max_rows", None)

# %%
df
# Out:
#                       Player  Matched_Played  Inns  No_Outs   Runs  \
# 0           DG Bradman (AUS)              52    80       10   6996
# 1             AC Voges (AUS)              20    31        7   1485
# 2            RG Pollock (SA)              23    41        4   2256
# 3            GA Headley (WI)              22    40        4   2190
# 5          H Sutcliffe (ENG)              54    84        9   4555
# 6             HC Brook (ENG)              15    24        1   1378
# 7            E Paynter (ENG)              20    31        5   1540
# 8        KF Barrington (ENG)              82   131       15   6806
# 9             ED Weekes (WI)              48    81        5   4455
# 10          WR Hammond (ENG)              85   140       16   7249
# 11            GS Sobers (WI)              93   160       21   8032
# 13        KC Sangakkara (SL)             134   233       17  12400
# 14           SPD Smith (AUS)             109   195       25   9685
# ...

# %%
df = df.drop(58, axis = 0)

# %%
df["Balls_Faced"] = df["Balls_Faced"].astype("int")

# %%
df.isnull().any()
# Out:
# Player                 False
# Matched_Played         False
# Inns                   False
# No_Outs                False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country_Or_State        True
# dtype: bool

# %%
df.dtypes
# Out:
# Player                  object
# Matched_Played           int64
# Inns                     int64
# No_Outs                  int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int64
# Final_Year               int64
# Country_Or_State        object
# dtype: object

# %%
df["Career_Length"] = df["Final_Year"] - df["Rookie_Year"]

# %%
df.dtypes
# Out:
# Player                  object
# Matched_Played           int64
# Inns                     int64
# No_Outs                  int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int64
# Final_Year               int64
# Country_Or_State        object
# Career_Length            int64
# dtype: object

# %%
df
# Out:
#                       Player  Matched_Played  Inns  No_Outs   Runs  \
# 0           DG Bradman (AUS)              52    80       10   6996
# 1             AC Voges (AUS)              20    31        7   1485
# 2            RG Pollock (SA)              23    41        4   2256
# 3            GA Headley (WI)              22    40        4   2190
# 5          H Sutcliffe (ENG)              54    84        9   4555
# 6             HC Brook (ENG)              15    24        1   1378
# 7            E Paynter (ENG)              20    31        5   1540
# 8        KF Barrington (ENG)              82   131       15   6806
# 9             ED Weekes (WI)              48    81        5   4455
# 10          WR Hammond (ENG)              85   140       16   7249
# 11            GS Sobers (WI)              93   160       21   8032
# 13        KC Sangakkara (SL)             134   233       17  12400
# 14           SPD Smith (AUS)             109   195       25   9685
# ...

# %%
df["Career_Length"].mean()
# Out:
# np.float64(13.229508196721312)

# %%
#show the average for every cricket players average batting strike rate
df[df["Career_Length"] > 10]["Batting_Strike_Rate"]
# Out:
# 0     58.60
# 3     56.00
# 5     34.59
# 8     42.42
# 10    38.07
# 11    53.58
# 13    54.19
# 14    53.50
# 15    46.22
# 17     0.00
# 18    39.34
# 19    45.97
# 21    51.41
# 24    51.53
# 25    63.88
# 26    54.04
# 27    60.51
# 28    45.99
# 29    42.51
# 30    52.39
# 31    52.12
# 32    58.72
# 36    43.31
# 37    43.35
# 38    48.64
# 39    60.10
# 40    54.51
# 41    41.09
# 43    69.77
# 44    56.71
# 45    38.81
# 46    51.45
# 47    54.02
# 49    40.16
# 50    30.04
# 51    82.23
# 53    55.56
# 55    55.92
# 57    29.11
# 59    46.92
# 60    43.74
# 61    49.16
# 62    59.67
# Name: Batting_Strike_Rate, dtype: float64

# %%
#get the average of career length that is more than 10 years and the total batting strike rate
df[df["Career_Length"] > 10]["Batting_Strike_Rate"].mean()
# Out:
# np.float64(49.06627906976744)

# %%
#find number of cricket player who play before 1960

# %%
df[df["Rookie_Year"] < 1960]
# Out:
#                  Player  Matched_Played  Inns  No_Outs  Runs  \
# 0      DG Bradman (AUS)              52    80       10  6996
# 3       GA Headley (WI)              22    40        4  2190
# 5     H Sutcliffe (ENG)              54    84        9  4555
# 7       E Paynter (ENG)              20    31        5  1540
# 8   KF Barrington (ENG)              82   131       15  6806
# 9        ED Weekes (WI)              48    81        5  4455
# 10     WR Hammond (ENG)              85   140       16  7249
# 11       GS Sobers (WI)              93   160       21  8032
# 15       JB Hobbs (ENG)              61   102        7  5410
# 17      CL Walcott (WI)              44    74        7  3798
# 18       L Hutton (ENG)              79   138       15  6971
# 20   GE Tyldesley (ENG)              14    20        2   990
# 25       AD Nourse (SA)              34    62        7  2960
# 33        J Ryder (AUS)              20    32        5  1394
# ...

# %%
df
# Out:
#                       Player  Matched_Played  Inns  No_Outs   Runs  \
# 0           DG Bradman (AUS)              52    80       10   6996
# 1             AC Voges (AUS)              20    31        7   1485
# 2            RG Pollock (SA)              23    41        4   2256
# 3            GA Headley (WI)              22    40        4   2190
# 5          H Sutcliffe (ENG)              54    84        9   4555
# 6             HC Brook (ENG)              15    24        1   1378
# 7            E Paynter (ENG)              20    31        5   1540
# 8        KF Barrington (ENG)              82   131       15   6806
# 9             ED Weekes (WI)              48    81        5   4455
# 10          WR Hammond (ENG)              85   140       16   7249
# 11            GS Sobers (WI)              93   160       21   8032
# 13        KC Sangakkara (SL)             134   233       17  12400
# 14           SPD Smith (AUS)             109   195       25   9685
# ...

# %%
df.groupby("Country_Or_State")["Highest_Inns_Score"].max().to_frame("HighInnCountry").reset_index().sort_values("HighInnCountry", ascending = False)
# Out:
#   Country_Or_State HighInnCountry
# 0              AUS            380
# 6               SL            374
# 7               WI            365
# 1              ENG            364
# 4              PAK            313
# 5               SA            278
# 2              IND            254
# 3               NZ            251
# 8              ZIM            232

# %%
df.groupby("Country_Or_State")[["100", "50", "0"]].mean()
# Out:
#                         100         50          0
# Country_Or_State
# AUS               20.625000  28.375000   8.562500
# ENG               13.166667  22.333333   4.416667
# IND               29.500000  36.500000  10.750000
# NZ                18.500000  22.000000   6.000000
# PAK               21.250000  28.000000   9.500000
# SA                 9.800000  20.200000   3.400000
# SL                28.666667  44.000000  12.333333
# WI                16.625000  25.625000   7.250000
# ZIM               12.000000  27.000000   5.000000
